# %%
import pandas as pd
import os
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import acf
import numpy as np
from scipy.signal import find_peaks
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %%
df_raw = pd.read_csv('dataset/ETTh1.csv')
scaler = StandardScaler()
cols_data = df_raw.columns[1:]
df_data = df_raw[cols_data]

train_data = df_data[:12*30*24]
scaler.fit(train_data.values)
data = scaler.transform(df_data.values)

train_data = data[:12*30*24]
test_data = data[16*30*24:20*30*24]


acf_values = acf(train_data[:,0], nlags=200)
# Find the secondary peak
peaks = np.argsort(acf_values)[::-1]  # Sort indices by ACF values in descending order
primary_peak = peaks[0]
secondary_peak = peaks[1] if peaks[1] != 0 else peaks[2]  # Ensure the secondary peak is not the zero lag

lags = np.arange(len(acf_values))
plt.figure(figsize=(3, 2.5))
plt.bar(lags, acf_values)

plt.xlim([0, 200])
plt.ylim([0, 1])

plt.xlabel("Lags", fontsize=10)
plt.ylabel("Autocorrelation", fontsize=10)

plt.grid(True)
plt.savefig('acf/etth1[0].pdf', bbox_inches='tight')
plt.show()

print(f"The secondary peak is at lag {secondary_peak} with an ACF value of {acf_values[secondary_peak]:.4f}")
# Out:
# The secondary peak is at lag 1 with an ACF value of 0.9247

# %%
df_raw = pd.read_csv('dataset/ETTh2.csv')
scaler = StandardScaler()
cols_data = df_raw.columns[1:]
df_data = df_raw[cols_data]

train_data = df_data[:12*30*24]
scaler.fit(train_data.values)
data = scaler.transform(df_data.values)

train_data = data[:12*30*24]
test_data = data[16*30*24:20*30*24]


acf_values = acf(train_data[:,6], nlags=200)


lags = np.arange(len(acf_values))
plt.figure(figsize=(3, 2.5))
plt.bar(lags, acf_values)

plt.xlim([0, 200])
plt.ylim([0.6, 1])

plt.xlabel("Lags", fontsize=10)
plt.ylabel("Autocorrelation", fontsize=10)

plt.grid(True)
plt.savefig('acf/etth2[6].pdf', bbox_inches='tight')

plt.show()

# %%
df_raw = pd.read_csv('dataset/ETTm1.csv')
scaler = StandardScaler()
cols_data = df_raw.columns[1:]
df_data = df_raw[cols_data]

train_data = df_data[:12*30*24*4]
scaler.fit(train_data.values)
data = scaler.transform(df_data.values)

train_data = data[:12*30*24*4]
test_data = data[16*30*24*4:20*30*24*4]


acf_values = acf(train_data[:,0], nlags=200)


lags = np.arange(len(acf_values))
plt.figure(figsize=(3, 2.5))
plt.bar(lags, acf_values)

plt.xlim([0, 200])
plt.ylim([0, 1])

plt.xlabel("Lags", fontsize=10)
plt.ylabel("Autocorrelation", fontsize=10)

plt.grid(True)
plt.savefig('acf/ettm1[0].pdf', bbox_inches='tight')
plt.show()

# %%
df_raw = pd.read_csv('dataset/ETTm2.csv')
scaler = StandardScaler()
cols_data = df_raw.columns[1:]
df_data = df_raw[cols_data]

train_data = df_data[:12*30*24*4]
scaler.fit(train_data.values)
data = scaler.transform(df_data.values)

train_data = data[:12*30*24*4]
test_data = data[16*30*24*4:20*30*24*4]


acf_values = acf(train_data[:,6], nlags=200)


lags = np.arange(len(acf_values))
plt.figure(figsize=(3, 2.5))
plt.bar(lags, acf_values)

plt.xlim([0, 200])
plt.ylim([0.7, 1])

plt.xlabel("Lags", fontsize=10)
plt.ylabel("Autocorrelation", fontsize=10)

plt.grid(True)
plt.savefig('acf/ettm2[6].pdf', bbox_inches='tight')
plt.show()

# %%
df_raw = pd.read_csv('dataset/electricity.csv')
scaler = StandardScaler()
cols_data = df_raw.columns[1:]
df_data = df_raw[cols_data]

train_data = df_data[:7*len(df_data)//10]
scaler.fit(train_data.values)
data = scaler.transform(df_data.values)

train_data = data[:7*len(df_data)//10]
test_data = data[9*len(df_data)//10:9]


acf_values = acf(train_data[:,320], nlags=200)
# Find the secondary peak
peaks = np.argsort(acf_values)[::-1]  # Sort indices by ACF values in descending order
primary_peak = peaks[0]
secondary_peak = peaks[1] if peaks[1] != 0 else peaks[2]  # Ensure the secondary peak is not the zero lag

lags = np.arange(len(acf_values))
plt.figure(figsize=(3, 2.5))
plt.bar(lags, acf_values)

plt.xlim([0, 200])
plt.ylim([0, 1])

plt.xlabel("Lags", fontsize=10)
plt.ylabel("Autocorrelation", fontsize=10)

plt.grid(True)
plt.savefig('acf/electricity[320].pdf', bbox_inches='tight')

plt.show()

print(f"The secondary peak is at lag {secondary_peak} with an ACF value of {acf_values[secondary_peak]:.4f}")
# Out:
# The secondary peak is at lag 1 with an ACF value of 0.9525

# %%
df_raw = pd.read_csv('dataset/traffic.csv')
scaler = StandardScaler()
cols_data = df_raw.columns[1:]
df_data = df_raw[cols_data]

train_data = df_data[:7*len(df_data)//10]
scaler.fit(train_data.values)
data = scaler.transform(df_data.values)

train_data = data[:7*len(df_data)//10]
test_data = data[9*len(df_data)//10:9]


acf_values = acf(train_data[:,606], nlags=200)


lags = np.arange(len(acf_values))
plt.figure(figsize=(3, 2.5))
plt.bar(lags, acf_values)

plt.xlim([0, 200])
plt.ylim([-0.4, 1])

plt.xlabel("Lags", fontsize=10)
plt.ylabel("Autocorrelation", fontsize=10)

plt.grid(True)
plt.savefig('acf/traffic[606].pdf', bbox_inches='tight')

plt.show()

# %%
df_raw = pd.read_csv('dataset/weather.csv')
scaler = StandardScaler()
cols_data = df_raw.columns[1:]
df_data = df_raw[cols_data]

train_data = df_data[:7*len(df_data)//10]
scaler.fit(train_data.values)
data = scaler.transform(df_data.values)

train_data = data[:7*len(df_data)//10]
test_data = data[9*len(df_data)//10:9]


acf_values = acf(train_data[:,16], nlags=200)


lags = np.arange(len(acf_values))
plt.figure(figsize=(3, 2.5))
plt.bar(lags, acf_values)

plt.xlim([0, 200])
plt.ylim([-0.5, 1])

plt.xlabel("Lags", fontsize=10)
plt.ylabel("Autocorrelation", fontsize=10)

plt.grid(True)
plt.savefig('acf/weather[16].pdf', bbox_inches='tight')

plt.show()

# %%
scaler = StandardScaler()
df_raw = []
with open('dataset/solar_AL.txt', "r", encoding='utf-8') as f:
    for line in f.readlines():
        line = line.strip('\n').split(',')
        data_line = np.stack([float(i) for i in line])
        df_raw.append(data_line)
df_raw = np.stack(df_raw, 0)
df_raw = pd.DataFrame(df_raw)
cols_data = df_raw.columns[1:]
df_data = df_raw[cols_data]

train_data = df_data[:7*len(df_data)//10]
scaler.fit(train_data.values)
data = scaler.transform(df_data.values)

train_data = data[:7*len(df_data)//10]
test_data = data[9*len(df_data)//10:9]


acf_values = acf(train_data[:,16], nlags=200)


lags = np.arange(len(acf_values))
plt.figure(figsize=(3, 2.5))
plt.bar(lags, acf_values)

plt.xlim([0, 200])
plt.ylim([-0.6, 1])

plt.xlabel("Lags", fontsize=10)
plt.ylabel("Autocorrelation", fontsize=10)

plt.grid(True)
plt.savefig('acf/solar[16].pdf', bbox_inches='tight')

plt.show()

# %% [markdown]
# solar数据集的acf图

# %%
df_raw = pd.read_csv('dataset/Solar_Power_Plant_Data.csv')
scaler = StandardScaler()
cols_data = df_raw.columns[1:]
df_data = df_raw[cols_data]

train_data = df_data[:]
scaler.fit(train_data.values)
data = scaler.transform(df_data.values)

train_data = data[:]
test_data = data[6*30*24:12*30*24]


acf_values = acf(train_data[:,-1], nlags=200)

# Detect local peaks in the ACF values
peaks, _ = find_peaks(acf_values)
# If the first detected peak is at lag 0 (trivial), choose the next one as the second peak
if len(peaks) > 0:
    if peaks[0] == 0 and len(peaks) > 1:
        second_peak = peaks[1]
    else:
        second_peak = peaks[0]
else:
    second_peak = None


lags = np.arange(len(acf_values))
plt.figure(figsize=(3, 2.5))
plt.bar(lags, acf_values)

plt.xlim([0, 200])
plt.ylim([0, 1])

plt.xlabel("Lags", fontsize=10)
plt.ylabel("Autocorrelation", fontsize=10)

plt.grid(True)
plt.savefig('acf/Solar_Power[0].pdf', bbox_inches='tight')
plt.show()

if second_peak is not None:
    print(f"The second peak is at lag {second_peak} with an ACF value of {acf_values[second_peak]:.4f}")
else:
    print("No second peak found in the ACF values.")
# Out:
# The second peak is at lag 24 with an ACF value of 0.7411

# %% [markdown]
# wind data

# %%
df_raw = pd.read_csv('dataset/wind_data.csv')
scaler = StandardScaler()
cols_data = df_raw.columns[15:-2]
df_data = df_raw[cols_data][1:]
train_data = df_data[:]
scaler.fit(train_data.values)
data = scaler.transform(df_data.values)

train_data = data[:]

acf_values = acf(train_data[:,27], nlags=365)
# Detect local peaks in the ACF values
peaks, _ = find_peaks(acf_values)
# If the first detected peak is at lag 0 (trivial), choose the next one as the second peak
if len(peaks) > 0:
    if peaks[0] == 0 and len(peaks) > 1:
        second_peak = peaks[1]
    else:
        second_peak = peaks[0]
else:
    second_peak = None


lags = np.arange(len(acf_values))
plt.figure(figsize=(3, 2.5))
plt.bar(lags, acf_values)

plt.xlim([0, 200])
plt.ylim([0, 1])

plt.xlabel("Lags", fontsize=10)
plt.ylabel("Autocorrelation", fontsize=10)

plt.grid(True)
plt.savefig('acf/Solar_Power[0].pdf', bbox_inches='tight')
plt.show()

if second_peak is not None:
    print(f"The second peak is at lag {second_peak} with an ACF value of {acf_values[second_peak]:.4f}")
else:
    print("No second peak found in the ACF values.")
# Out:
# /opt/anaconda3/envs/CycleNet/lib/python3.8/site-packages/sklearn/utils/extmath.py:1050: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /opt/anaconda3/envs/CycleNet/lib/python3.8/site-packages/sklearn/utils/extmath.py:1055: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /opt/anaconda3/envs/CycleNet/lib/python3.8/site-packages/sklearn/utils/extmath.py:1075: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
# The second peak is at lag 35 with an ACF value of 0.2433
